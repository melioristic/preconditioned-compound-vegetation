# %%
import xarray as xr

# %%
temp_path = "/data/compoundx/anand/PCV/data/detrended_seasonal_t2m.nc"
tp_path = "/data/compoundx/ERA5/MohitBudapestProject/tp.monthly.era5.nhemisphere.1981-2020.nc"
ssrd_path = "/data/compoundx/ERA5/MohitBudapestProject/ssrd.monthly.era5.nhemisphere.1981-2020.nc"
swvlall_path = "/data/compoundx/ERA5/MohitBudapestProject/swvlall.monthly.era5.nhemisphere.1981-2020.nc"
vpd_path = "/data/compoundx/ERA5/MohitBudapestProject/vpd_cf.monthly.era5.nhemisphere.1981-2020.nc"
sd_path = "/data/compoundx/ERA5/MohitBudapestProject/sd.monthly.era5.nhemisphere.1981-2020.nc"
lai_path = "/data/compoundx/anand/PCV/data/detrended_seasonal_lai.nc"
smroot_path = "/data/compoundx/anand/PCV/data/SMroot_1980-2021_MO.nc"


t2m_data = xr.open_dataset(temp_path)
lai_data = xr.open_dataset(lai_path)

# %%
t2m_data
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 200, time: 161)
# Coordinates:
#   * longitude  (longitude) float64 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
#   * latitude   (latitude) float64 74.88 74.62 74.38 74.12 ... 25.62 25.38 25.12
#   * time       (time) datetime64[ns] 1980-12-01 1981-03-01 ... 2020-12-01
# Data variables:
#     t2m        (time, latitude, longitude) float64 ...

# %%
lai_data
# Out:
# <xarray.Dataset>
# Dimensions:      (lon: 1440, lat: 200, time: 157)
# Coordinates:
#   * lon          (lon) float64 -179.9 -179.6 -179.4 -179.1 ... 179.4 179.6 179.9
#   * lat          (lat) float64 25.12 25.38 25.62 25.88 ... 74.38 74.62 74.88
#   * time         (time) datetime64[ns] 1981-12-01 1982-03-01 ... 2020-12-01
# Data variables:
#     GLOBMAP_LAI  (time, lat, lon) float64 ...
