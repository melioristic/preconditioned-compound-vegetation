# %%
import xarray as xr

# %%
swvlall_path = "/data/compoundx/anand/PCV/data/detrended_seasonal_swvlall.nc"
sm_path = "/data/compoundx/anand/PCV/data/detrended_seasonal_smroot.nc"

# %%
swvlall_data = xr.open_dataset(swvlall_path)
sm_data = xr.open_dataset(sm_path)

# %%
swvlall_data["swvlall"][100,:,:].plot()

# %%
sm_data["SMroot"][20,:,:].plot()

# %%
swvlall_data
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 200, time: 161)
# Coordinates:
#   * longitude  (longitude) float64 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
#   * latitude   (latitude) float64 74.88 74.62 74.38 74.12 ... 25.62 25.38 25.12
#   * time       (time) datetime64[ns] 1980-12-01 1981-03-01 ... 2020-12-01
# Data variables:
#     swvlall    (time, latitude, longitude) float64 ...
